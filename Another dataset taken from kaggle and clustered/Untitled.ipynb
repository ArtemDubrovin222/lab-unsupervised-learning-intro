# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
list = pd.read_csv('tcc_ceds_music.csv')
list
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
list.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'release_date', 'genre',
#        'lyrics', 'len', 'dating', 'violence', 'world/life', 'night/time',
#        'shake the audience', 'family/gospel', 'romantic', 'communication',
#        'obscene', 'music', 'movement/places', 'light/visual perceptions',
#        'family/spiritual', 'like/girls', 'sadness', 'feelings', 'danceability',
#        'loudness', 'acousticness', 'instrumentalness', 'valence', 'energy',
#        'topic', 'age'],
#       dtype='object')

# %%
n_list = list.select_dtypes(include='number')

# %%
transformer = StandardScaler().fit(n_list)
X_prep=transformer.transform(n_list)
pd.DataFrame(X_prep,columns=n_list.columns).head()
# Out:
#    Unnamed: 0  release_date       len    dating  violence  world/life  \
# 0   -1.735283      -2.17648  0.525270 -0.391712 -0.305855   -0.699056
# 1   -1.735121      -2.17648 -0.526630  0.275459 -0.120996    1.872639
# 2   -1.735040      -2.17648 -1.172113 -0.350237 -0.647112   -0.686443
# 3   -1.734879      -2.17648 -0.454909  0.518198 -0.653951   -0.693540
# 4   -1.734798      -2.17648 -0.598350 -0.377363 -0.655062    1.723607
#
#    night/time  shake the audience  family/gospel  romantic  ...  like/girls  \
# 0   -0.507401           -0.413684       0.758051 -0.297631  ...   -0.469610
# 1   -0.501275           -0.396826       0.237390 -0.446751  ...   -0.457884
# 2   -0.487995           -0.360278      -0.340172  1.035725  ...   -0.432464
# 3   -0.498914            0.100271      -0.369294  3.420147  ...    0.907699
# 4   -0.500687           -0.395207      -0.374023  3.909285  ...   -0.456758
#
#     sadness  feelings  danceability  loudness  acousticness  instrumentalness  \
# ...

# %%
kmeans = KMeans(n_clusters=20, random_state=1234)
kmeans.fit(X_prep)
# Out:
# C:\Users\lilly\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=20, random_state=1234)

# %%
clusters = kmeans.predict(X_prep)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0     1243
# 1     2008
# 2     1625
# 3     3046
# 4     1417
# 5     1976
# 6     2357
# 7     1331
# 8      609
# 9     1393
# 10    2138
# 11     726
# 12     778
# 13    1322
# 14     707
# 15     909
# 16    1692
# 17    1375
# 18    1064
# 19     656
# Name: count, dtype: int64

# %%
list['cluster']= clusters
list
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28367       82447               mack 10                10 million ways
# 28368       82448                m.o.p.  ante up (robbin hoodz theory)
# 28369       82449                  nine                  whutcha want?
# 28370       82450            will smith                         switch
# 28371       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
list_clusters = list[['track_name', 'artist_name', 'release_date', 'genre', 'cluster']]
list_clusters
# Out:
#                           track_name           artist_name  release_date  \
# 0               mohabbat bhi jhoothi                mukesh          1950
# 1                          i believe         frankie laine          1950
# 2                                cry           johnnie ray          1950
# 3                           patricia           pérez prado          1950
# 4                 apopse eida oneiro  giorgos papadopoulos          1950
# ...                              ...                   ...           ...
# 28367                10 million ways               mack 10          2019
# 28368  ante up (robbin hoodz theory)                m.o.p.          2019
# 28369                  whutcha want?                  nine          2019
# 28370                         switch            will smith          2019
# 28371                         r.i.p.                 jeezy          2019
#
#          genre  cluster
# 0          pop        1
# 1          pop       16
# ...

# %%
list_clusters.to_csv('cluster_list.csv', index=False)
