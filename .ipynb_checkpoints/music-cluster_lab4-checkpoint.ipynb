# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn import cluster, datasets
from sklearn.preprocessing import StandardScaler
from matplotlib.lines import Line2D
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
list = pd.read_csv('music.csv')
list
# Out:
#               song_name         name                 song_id  popularity  \
# 0      Die in This Town    The Seige  0bqrFwY1HixfnusFxhYbDl        56.0
# 1                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi        49.0
# 2                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi        49.0
# 3             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS        54.0
# 4             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS        54.0
# ...                 ...          ...                     ...         ...
# 14217  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk        57.0
# 14218  Crossed The Line        Vosai  1j3N4TCykSmXy12iUiMQWk        57.0
# 14219  Crossed The Line     Facading  1j3N4TCykSmXy12iUiMQWk        57.0
# 14220  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk        57.0
# 14221    Planeta Zombie    FIZIstyle  1v5xDpNIw3OgLDhif8buEG        38.0
#
#        danceability  energy  key  loudness  mode  speechiness  ...  liveness  \
# 0             0.685   0.746  5.0    -4.558   1.0       0.2740  ...     0.320
# 1             0.583   0.856  6.0    -5.446   0.0       0.0445  ...     0.224
# 2             0.583   0.856  6.0    -5.446   0.0       0.0445  ...     0.224
# 3             0.827   0.791  1.0    -6.030   1.0       0.0841  ...     0.166
# 4             0.827   0.791  1.0    -6.030   1.0       0.0841  ...     0.166
# ...             ...     ...  ...       ...   ...          ...  ...       ...
# 14217         0.533   0.723  2.0    -7.076   0.0       0.1990  ...     0.297
# 14218         0.533   0.723  2.0    -7.076   0.0       0.1990  ...     0.297
# 14219         0.533   0.723  2.0    -7.076   0.0       0.1990  ...     0.297
# 14220         0.533   0.723  2.0    -7.076   0.0       0.1990  ...     0.297
# 14221         0.793   0.926  9.0    -2.394   0.0       0.1020  ...     0.054
#
#        valence    tempo            type                      id  \
# 0        0.594   64.950  audio_features  0bqrFwY1HixfnusFxhYbDl
# 1        0.480  168.053  audio_features  4WZ3liyYz5ZzDcL4ibAuOi
# 2        0.480  168.053  audio_features  4WZ3liyYz5ZzDcL4ibAuOi
# 3        0.720   95.000  audio_features  39kS4TwUw5yTJETWusq2VS
# 4        0.720   95.000  audio_features  39kS4TwUw5yTJETWusq2VS
# ...        ...      ...             ...                     ...
# 14217    0.388  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14218    0.388  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14219    0.388  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14220    0.388  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14221    0.973  156.032  audio_features  1v5xDpNIw3OgLDhif8buEG
#
#                                         uri  \
# 0      spotify:track:0bqrFwY1HixfnusFxhYbDl
# 1      spotify:track:4WZ3liyYz5ZzDcL4ibAuOi
# 2      spotify:track:4WZ3liyYz5ZzDcL4ibAuOi
# 3      spotify:track:39kS4TwUw5yTJETWusq2VS
# 4      spotify:track:39kS4TwUw5yTJETWusq2VS
# ...                                     ...
# 14217  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14218  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14219  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14220  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14221  spotify:track:1v5xDpNIw3OgLDhif8buEG
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0bqrFwY1Hixf...
# 1      https://api.spotify.com/v1/tracks/4WZ3liyYz5Zz...
# 2      https://api.spotify.com/v1/tracks/4WZ3liyYz5Zz...
# 3      https://api.spotify.com/v1/tracks/39kS4TwUw5yT...
# 4      https://api.spotify.com/v1/tracks/39kS4TwUw5yT...
# ...                                                  ...
# 14217  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14218  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14219  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14220  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14221  https://api.spotify.com/v1/tracks/1v5xDpNIw3Og...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0bqr...    151500.0
# 1      https://api.spotify.com/v1/audio-analysis/4WZ3...    178973.0
# 2      https://api.spotify.com/v1/audio-analysis/4WZ3...    178973.0
# 3      https://api.spotify.com/v1/audio-analysis/39kS...    186947.0
# 4      https://api.spotify.com/v1/audio-analysis/39kS...    186947.0
# ...                                                  ...         ...
# 14217  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14218  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14219  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14220  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14221  https://api.spotify.com/v1/audio-analysis/1v5x...    153077.0
#
#       time_signature
# 0                4.0
# 1                4.0
# 2                4.0
# 3                4.0
# 4                4.0
# ...              ...
# 14217            4.0
# 14218            4.0
# 14219            4.0
# 14220            4.0
# 14221            4.0
#
# [14222 rows x 22 columns]

# %%
n_list = list.select_dtypes(include='number')

# %%
transformer = StandardScaler().fit(n_list)
X_prep=transformer.transform(n_list)
pd.DataFrame(X_prep,columns=n_list.columns).head()
# Out:
#    popularity  danceability    energy       key  loudness      mode  \
# 0    1.206172      0.532570  0.409030 -0.081764  0.776562  0.905832
# 1    0.917832      0.075446  0.773831  0.210336  0.682448 -1.103957
# 2    0.917832      0.075446  0.773831  0.210336  0.682448 -1.103957
# 3    1.123789      1.168959  0.558267 -1.250167  0.620553  0.905832
# 4    1.123789      1.168959  0.558267 -1.250167  0.620553  0.905832
#
#    speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 0     1.292461     -0.954485         -0.752523  0.272635  0.815706 -1.727112
# 1    -0.610425     -0.976080         -0.752523 -0.111801  0.381042  1.567987
# 2    -0.610425     -0.976080         -0.752523 -0.111801  0.381042  1.567987
# 3    -0.282084     -0.881680         -0.752523 -0.344064  1.296124 -0.766735
# 4    -0.282084     -0.881680         -0.752523 -0.344064  1.296124 -0.766735
#
#    duration_ms  time_signature
# 0    -0.098726        0.227886
# 1     0.052318        0.227886
# 2     0.052318        0.227886
# 3     0.096158        0.227886
# 4     0.096158        0.227886

# %%
#Had a lot of warning for next 2 graphs, removed it not to have a lot of red messages
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
K = range(2, 20)
inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
K = range(2, 20)
silhouette = []

for k in K:
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_prep)
    silhouette.append(silhouette_score(X_prep, kmeans.predict(X_prep)))


plt.figure(figsize=(16,8))
plt.plot(K, silhouette, 'bx-')
plt.xlabel('k')
plt.ylabel('silhouette score')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Slhouette score showing the optimal k')
# Out:
# Text(0.5, 1.0, 'Slhouette score showing the optimal k')

# %%
kmeans = KMeans(n_clusters=20, random_state=1234)
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=20, random_state=1234)

# %%
clusters = kmeans.predict(X_prep)
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0      641
# 1      858
# 2      685
# 3      788
# 4      904
# 5       45
# 6      696
# 7     1034
# 8      595
# 9      710
# 10     599
# 11     268
# 12     514
# 13     950
# 14     874
# 15    1141
# 16     977
# 17     520
# 18     764
# 19     659
# Name: count, dtype: int64

# %%
list['cluster']= clusters
list
# Out:
#               song_name         name                 song_id  popularity  \
# 0      Die in This Town    The Seige  0bqrFwY1HixfnusFxhYbDl        56.0
# 1                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi        49.0
# 2                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi        49.0
# 3             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS        54.0
# 4             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS        54.0
# ...                 ...          ...                     ...         ...
# 14217  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk        57.0
# 14218  Crossed The Line        Vosai  1j3N4TCykSmXy12iUiMQWk        57.0
# 14219  Crossed The Line     Facading  1j3N4TCykSmXy12iUiMQWk        57.0
# 14220  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk        57.0
# 14221    Planeta Zombie    FIZIstyle  1v5xDpNIw3OgLDhif8buEG        38.0
#
#        danceability  energy  key  loudness  mode  speechiness  ...  valence  \
# 0             0.685   0.746  5.0    -4.558   1.0       0.2740  ...    0.594
# 1             0.583   0.856  6.0    -5.446   0.0       0.0445  ...    0.480
# 2             0.583   0.856  6.0    -5.446   0.0       0.0445  ...    0.480
# 3             0.827   0.791  1.0    -6.030   1.0       0.0841  ...    0.720
# 4             0.827   0.791  1.0    -6.030   1.0       0.0841  ...    0.720
# ...             ...     ...  ...       ...   ...          ...  ...      ...
# 14217         0.533   0.723  2.0    -7.076   0.0       0.1990  ...    0.388
# 14218         0.533   0.723  2.0    -7.076   0.0       0.1990  ...    0.388
# 14219         0.533   0.723  2.0    -7.076   0.0       0.1990  ...    0.388
# 14220         0.533   0.723  2.0    -7.076   0.0       0.1990  ...    0.388
# 14221         0.793   0.926  9.0    -2.394   0.0       0.1020  ...    0.973
#
#          tempo            type                      id  \
# 0       64.950  audio_features  0bqrFwY1HixfnusFxhYbDl
# 1      168.053  audio_features  4WZ3liyYz5ZzDcL4ibAuOi
# 2      168.053  audio_features  4WZ3liyYz5ZzDcL4ibAuOi
# 3       95.000  audio_features  39kS4TwUw5yTJETWusq2VS
# 4       95.000  audio_features  39kS4TwUw5yTJETWusq2VS
# ...        ...             ...                     ...
# 14217  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14218  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14219  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14220  176.096  audio_features  1j3N4TCykSmXy12iUiMQWk
# 14221  156.032  audio_features  1v5xDpNIw3OgLDhif8buEG
#
#                                         uri  \
# 0      spotify:track:0bqrFwY1HixfnusFxhYbDl
# 1      spotify:track:4WZ3liyYz5ZzDcL4ibAuOi
# 2      spotify:track:4WZ3liyYz5ZzDcL4ibAuOi
# 3      spotify:track:39kS4TwUw5yTJETWusq2VS
# 4      spotify:track:39kS4TwUw5yTJETWusq2VS
# ...                                     ...
# 14217  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14218  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14219  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14220  spotify:track:1j3N4TCykSmXy12iUiMQWk
# 14221  spotify:track:1v5xDpNIw3OgLDhif8buEG
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/0bqrFwY1Hixf...
# 1      https://api.spotify.com/v1/tracks/4WZ3liyYz5Zz...
# 2      https://api.spotify.com/v1/tracks/4WZ3liyYz5Zz...
# 3      https://api.spotify.com/v1/tracks/39kS4TwUw5yT...
# 4      https://api.spotify.com/v1/tracks/39kS4TwUw5yT...
# ...                                                  ...
# 14217  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14218  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14219  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14220  https://api.spotify.com/v1/tracks/1j3N4TCykSmX...
# 14221  https://api.spotify.com/v1/tracks/1v5xDpNIw3Og...
#
#                                             analysis_url duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/0bqr...    151500.0
# 1      https://api.spotify.com/v1/audio-analysis/4WZ3...    178973.0
# 2      https://api.spotify.com/v1/audio-analysis/4WZ3...    178973.0
# 3      https://api.spotify.com/v1/audio-analysis/39kS...    186947.0
# 4      https://api.spotify.com/v1/audio-analysis/39kS...    186947.0
# ...                                                  ...         ...
# 14217  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14218  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14219  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14220  https://api.spotify.com/v1/audio-analysis/1j3N...    147273.0
# 14221  https://api.spotify.com/v1/audio-analysis/1v5x...    153077.0
#
#       time_signature cluster
# 0                4.0      13
# 1                4.0      15
# 2                4.0      15
# 3                4.0      13
# 4                4.0      13
# ...              ...     ...
# 14217            4.0      15
# 14218            4.0      15
# 14219            4.0      15
# 14220            4.0      15
# 14221            4.0       3
#
# [14222 rows x 23 columns]

# %%
list_clusters = list[['song_name', 'name', 'song_id', 'cluster']]
list_clusters
# Out:
#               song_name         name                 song_id  cluster
# 0      Die in This Town    The Seige  0bqrFwY1HixfnusFxhYbDl       13
# 1                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi       15
# 2                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi       15
# 3             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS       13
# 4             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS       13
# ...                 ...          ...                     ...      ...
# 14217  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk       15
# 14218  Crossed The Line        Vosai  1j3N4TCykSmXy12iUiMQWk       15
# 14219  Crossed The Line     Facading  1j3N4TCykSmXy12iUiMQWk       15
# 14220  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk       15
# 14221    Planeta Zombie    FIZIstyle  1v5xDpNIw3OgLDhif8buEG        3
#
# [14222 rows x 4 columns]

# %%
list_clusters = list_clusters.rename(columns={'name': 'singer'})

# %%
list_clusters
# Out:
#               song_name       singer                 song_id  cluster
# 0      Die in This Town    The Seige  0bqrFwY1HixfnusFxhYbDl       13
# 1                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi       15
# 2                 Grand   Kane Brown  4WZ3liyYz5ZzDcL4ibAuOi       15
# 3             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS       13
# 4             Statement       NEFFEX  39kS4TwUw5yTJETWusq2VS       13
# ...                 ...          ...                     ...      ...
# 14217  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk       15
# 14218  Crossed The Line        Vosai  1j3N4TCykSmXy12iUiMQWk       15
# 14219  Crossed The Line     Facading  1j3N4TCykSmXy12iUiMQWk       15
# 14220  Crossed The Line  Linn Sandin  1j3N4TCykSmXy12iUiMQWk       15
# 14221    Planeta Zombie    FIZIstyle  1v5xDpNIw3OgLDhif8buEG        3
#
# [14222 rows x 4 columns]

# %%
list_clusters.to_csv('cluster_list', index=False)
